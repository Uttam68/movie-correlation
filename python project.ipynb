# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ACER'

# %%
os.chdir(r'C:\Users\ACER\Downloads')
os.getcwd()
# Out:
# 'C:\\Users\\ACER\\Downloads'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)


df=pd.read_csv(r'movies.csv.zip')

# %%
#let's look at the data
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#cheking for null values
for col in df.columns:
    print(col," - ",np.sum(df[col].isnull()))
# Out:
# name  -  0
# rating  -  77
# genre  -  0
# year  -  0
# released  -  2
# score  -  3
# votes  -  3
# director  -  0
# writer  -  3
# star  -  1
# country  -  3
# budget  -  2171
# gross  -  189
# company  -  17
# runtime  -  4

# %%
#dealing with the null values the null values
df.dropna(inplace=True)

# %%
#datatypes of each column
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#changing the data types of vote,budget and gross because we don't need the extra zero after the decimal
df['votes']=df['votes'].astype('int64')
df['budget']=df['budget'].astype('int64')
df['gross']=df['gross'].astype('int64')

# %%
#ordering the data frame with respect to the gross
df.sort_values(by=['gross'],inplace=False,ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes             director  \
# ...

# %%
#Dropping duplicate rows
df=df.drop_duplicates()

# %%
#finding the correlation between budget and gross
#scatter plot of budget vs gross 

plt.scatter(df['budget'],df['gross'])
plt.title("Budget vs Gross scatter plot")
plt.xlabel('Budget for film')
plt.ylabel('Gross earnings')
plt.show()

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
#plot the budget vs gross using regplot
sns.regplot(df['budget'],df['gross'],data=df,scatter_kws={"color":"red"},line_kws={"color":"yellow"})
plt.show()
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#finding correlation among numerical values
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
cormax=df.corr()
sns.heatmap(cormax,annot=True,cmap="Blues")
plt.title("Correlation Matrix across numerical features")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
# Out:
# Text(87.0, 0.5, 'Movie Features')

# %%
#Encoding Categorical Data

df_converted=df

for i in df_converted.columns:
    if(df_converted[i].dtype=="object"):
        df_converted[i]=df_converted[i].astype("category")
        df_converted[i]=df_converted[i].cat.codes

# %%
df_converted
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 0     4692       6      6  1980      1304    8.4   927000      1795    2832
# 1     3929       6      1  1980      1127    5.8    65000      1578    1158
# 2     3641       4      0  1980      1359    8.7  1200000       757    1818
# 3      204       4      4  1980      1127    7.7   221000       889    1413
# 4      732       6      4  1980      1170    7.3   108000       719     351
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 7648   415       6      0  2020       904    6.6   140000        16    2390
# 7649  3556       4      0  2020       713    6.5   102000       852    2309
# 7650  1153       4      1  2020       904    5.6    53000      1809    2827
# 7651  3978       4      1  2020       758    6.8    42000       294    2091
# 7652  4090       3      0  2020       370    6.8     3700       746    1184
#
# ...

# %%
#New correlation

cormax2=df_converted.corr()
plt.figure(figsize=(12,7))
sns.heatmap(cormax2,annot=True,cmap="Blues")
plt.title("Correlation Matrix across all features")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
# Out:
# Text(87.0, 0.5, 'Movie Features')

# %%
#finding all the correlation pairs
corpairs=df_converted.corr()
corpairs=corpairs.unstack()
sorted_corpairs=corpairs.sort_values()
sorted_corpairs
# Out:
# budget   genre     -0.368523
# genre    budget    -0.368523
#          gross     -0.244101
# gross    genre     -0.244101
# budget   rating    -0.203946
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
#finding the high correlated domains
highestcor=sorted_corpairs[(sorted_corpairs)>0.5]
highestcor
# Out:
# votes     gross       0.614751
# gross     votes       0.614751
#           budget      0.740247
# budget    gross       0.740247
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
# we concluded that votes and budget have the highest correlation with the gross revenue
